# %%
import sphn
import json
from pathlib import Path

paths = [str(f) for f in Path(
    "/users/s1f102201582/projects/mhcc-moshi/moshi/data/v1/data_stereo"
).glob("*.wav")]
durations = sphn.durations(paths)

with open("/users/s1f102201582/projects/mhcc-moshi/moshi/data/v1/data.jsonl", "w") as fobj:
    for p, d in zip(paths, durations):
        if d is None:
            continue
        json.dump({"path": p, "duration": d}, fobj)
        fobj.write("\n")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import sphn
#       2 import json
#       3 from pathlib import Path
#
# ModuleNotFoundError: No module named 'sphn'

# %%
# !python /users/s1f102201582/projects/moshi-finetune/annotate.py /users/s1f102201582/projects/mhcc-moshi/moshi/data/v1/data.jsonl \
    --whisper_model "large-v3-turbo" \
    --lang "ja" \
    --local
# Out:
# [11-11 18:46:35][__main__][INFO] - Hello, world, this is shard 0 / 1.
# [11-11 18:46:35][__main__][INFO] - Loading all models.
#  13%|█████▎                                 | 208M/1.51G [00:01<00:12, 113MiB/s]^C
#  14%|█████▎                                 | 212M/1.51G [00:02<00:12, 110MiB/s]
# Traceback (most recent call last):
#   File "/nfs1/s1f102201582/projects/moshi-finetune/annotate.py", line 295, in <module>
#     main()
#   File "/nfs1/s1f102201582/projects/moshi-finetune/annotate.py", line 263, in main
#     run(params)
#   File "/nfs1/s1f102201582/projects/moshi-finetune/annotate.py", line 163, in run
#     w_model = whisper.load_model(params.whisper_model, device=device)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/nfs1/s1f102201582/anaconda3/envs/moshi/lib/python3.12/site-packages/whisper_timestamped/transcribe.py", line 2472, in load_model
#     return whisper.load_model(
#            ^^^^^^^^^^^^^^^^^^^
# ...
