# %%
# !python -m moshi.run_tts \
--tokenizer jmoshi_model/tokenizer_spm_32k_3.model \
--mimi-weight jmoshi_model/tokenizer-e351c8d8-checkpoint125.safetensors \
--moshi-weight jmoshi_model/model.safetensors \
tts.jsonl

# --lm-config jmoshi_model/moshi_lm_kwargs.json \
# --tokenizer jmoshi_model/tokenizer_spm_32k_3.model \
# --mimi-weight jmoshi_model/tokenizer-e351c8d8-checkpoint125.safetensors \
# --moshi-weight jmoshi_model/model.safetensors \
# Out:
# retrieving checkpoint
# Traceback (most recent call last):
#   File "/nfs1/s1f102201582/anaconda3/envs/moshi-tts/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/nfs1/s1f102201582/anaconda3/envs/moshi-tts/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/nfs1/s1f102201582/anaconda3/envs/moshi-tts/lib/python3.10/site-packages/moshi/run_tts.py", line 213, in <module>
#     main()
#   File "/nfs1/s1f102201582/anaconda3/envs/moshi-tts/lib/python3.10/site-packages/moshi/run_tts.py", line 88, in main
#     tts_model = TTSModel.from_checkpoint_info(
#   File "/nfs1/s1f102201582/anaconda3/envs/moshi-tts/lib/python3.10/site-packages/moshi/models/tts.py", line 398, in from_checkpoint_info
#     lm = checkpoint_info.get_moshi(device=device, dtype=dtype)
#   File "/nfs1/s1f102201582/anaconda3/envs/moshi-tts/lib/python3.10/site-packages/moshi/models/loaders.py", line 271, in get_moshi
# ...
